# %% [markdown]
# > This notebook is created to verify the existance of the 9 challenge datasets (csv´s)

# %% [markdown]
# # Library import

# %%
import pandas as pd

# %% [markdown]
# ### Dataset inspection

# %%
from __future__ import annotations

from pathlib import Path
from typing import Iterable, Dict, Any

import pandas as pd

# Paths
PROJECT_ROOT = Path.cwd()
RAW_DIR = PROJECT_ROOT / "data" / "raw"
INTERIM_DIR = PROJECT_ROOT / "data" / "interim"
INTERIM_DIR.mkdir(parents=True, exist_ok=True)

# Expected files (train_labels.csv does NOT exist in the public challenge)
EXPECTED = {
    "train_operational_readouts.csv",
    "train_tte.csv",
    "train_specifications.csv",
    "validation_operational_readouts.csv",
    "validation_labels.csv",
    "validation_specifications.csv",
    "test_operational_readouts.csv",
    "test_specifications.csv",
    # If you truly have it, include test_labels.csv (some bundles provide it)
    "test_labels.csv",
}

# Audit settings
SAMPLE_ROWS = 1000         # rows to load for schema preview
COUNT_ROWS = False         # WARNING: can be slow for very large CSVs
ENCODING = "utf-8"         # adjust if needed
