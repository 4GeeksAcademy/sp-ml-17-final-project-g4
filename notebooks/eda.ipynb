# %% [markdown]
# ### Library import

# %%
# === Setup: Ensure we can import from src/ anywhere ===
import sys
from pathlib import Path

# Detect project root by looking for .git folder
current_dir = Path.cwd().resolve()
for parent in [current_dir] + list(current_dir.parents):
    if (parent / ".git").exists():
        PROJECT_ROOT = parent
        break
else:
    raise FileNotFoundError("Could not find project root (.git not found)")

# Add project root to Python path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"✅ Project root set to: {PROJECT_ROOT}")

# Now we can import from src/
from src.load_data import load_csv
from src.paths import RAW_DIR

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
sns.set(style="whitegrid")
# Out:
# ✅ Project root set to: C:\Users\J Vicente\OneDrive\Documentos\GitHub\sp-ml-17-final-project-g4

# %% [markdown]
# ##### List all CSV files in the raw data folder

# %%
csv_files = list(RAW_DIR.glob("*.csv"))
if not csv_files:
    raise FileNotFoundError(f"No CSV files found in {RAW_DIR}")
print(f"Found {len(csv_files)} CSV files in raw data folder:")
for f in csv_files:
    print(f" - {f.name}")
# Out:
# Found 9 CSV files in raw data folder:
#  - test_labels.csv
#  - test_operational_readouts.csv
#  - test_specifications.csv
#  - train_operational_readouts.csv
#  - train_specifications.csv
#  - train_tte.csv
#  - validation_labels.csv
#  - validation_operational_readouts.csv
#  - validation_specifications.csv

# %% [markdown]
# > Due to file size. Load a small sample to inspect structure

# %%
sample_df = load_csv(csv_files[0].name, nrows=5)
sample_df
# Out:
#    vehicle_id  class_label
# 0           1            0
# 1           6            0
# 2           7            0
# 3           9            0
# 4          11            0

# %% [markdown]
# #### General Info

# %%
df = load_csv(csv_files[0].name) # Load full dataset
df.shape
# Out:
# (5045, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5045 entries, 0 to 5044
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vehicle_id   5045 non-null   int64
#  1   class_label  5045 non-null   int64
# dtypes: int64(2)
# memory usage: 79.0 KB

# %% [markdown]
# #### Basic statistics

# %%
df.describe(include="all").T
# Out:
#               count          mean          std  min     25%      50%      75%  \
# vehicle_id   5045.0  16803.188702  9761.914799  1.0  8300.0  16755.0  25299.0
# class_label  5045.0      0.083053     0.523099  0.0     0.0      0.0      0.0
#
#                  max
# vehicle_id   33638.0
# class_label      4.0

# %% [markdown]
# ##### Null values

# %%
nulls = df.isna().sum()
nulls = nulls[nulls > 0].sort_values(ascending=False)
print(f"Columns with missing values: {len(nulls)}")
nulls
# Out:
# Columns with missing values: 0
# Series([], dtype: int64)
